# %% [markdown]
# <a href="https://colab.research.google.com/github/Marvimnas/Box_Plot-Python/blob/main/DEAComparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
data = pd.read_csv('/content/drive/My Drive/Data/ComparaDEA.txt') #subir um arquivo txt em que cada coluna é um modelo DEA

# %%
data.head(50)
# Out:
#         NDEA       CCR       BCC
# 0   0.554484  0.306623  0.728293
# 1   0.555091  0.306618  0.889364
# 2   0.555244  0.306625  0.779092
# 3   0.523774  0.292643  0.645384
# 4   0.523749  0.292640  0.613573
# 5   0.523667  0.292643  0.616934
# 6   0.544057  0.300409  0.622688
# 7   0.544354  0.300409  0.687831
# 8   0.544153  0.300404  0.681800
# 9   0.598577  0.374006  0.680994
# 10  0.598641  0.374001  0.702083
# 11  0.598586  0.374000  0.645245
# 12  0.561885  0.329818  0.568868
# 13  0.562065  0.329821  0.691054
# 14  0.562081  0.329821  0.643695
# 15  0.709987  0.585299  0.691097
# 16  0.710021  0.585275  0.697440
# 17  0.710027  0.585288  0.711102
# 18  0.822377  0.999987  1.000000
# 19  0.822343  1.000000  1.000000
# 20  0.822453  0.999994  1.000000
# 21  0.583504  0.386275  0.492893
# 22  0.583498  0.386273  0.518722
# 23  0.583540  0.386274  0.480291
# 24  0.653839  0.489249  0.537115
# 25  0.653907  0.489233  0.658243
# 26  0.653950  0.489250  0.635867
# ...

# %%
stats_summary = data.describe()
print("Statistical Summary:\n", stats_summary)
# Out:
# Statistical Summary:
#               NDEA         CCR         BCC
# count  107.000000  107.000000  107.000000
# mean     0.683587    0.595155    0.713936
# std      0.094121    0.200412    0.142863
# min      0.523667    0.292640    0.480291
# 25%      0.625215    0.455097    0.621105
# 50%      0.676045    0.560419    0.687100
# 75%      0.726753    0.699064    0.774979
# max      0.982002    1.000000    1.000000

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=data)
plt.title("Box-Plot of DEA Models")
plt.show()
